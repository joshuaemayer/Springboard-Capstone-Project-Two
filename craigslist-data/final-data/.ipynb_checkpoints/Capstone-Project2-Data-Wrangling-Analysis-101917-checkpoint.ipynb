# %% [markdown]
# # Capstone Project 2 - Data Wrangling & Analysis

# %%
import pandas as pd #for building pandas dataframes for analysis
import re #for parsing file names
import glob, os #for reading file names
import datetime # for tracking API call counts
import numpy as np
import nltk # for interpretation of text and text analysis
from nltk.corpus import stopwords # Import the stop word list
from sklearn.feature_extraction.text import CountVectorizer #for bag of words analysis
import seaborn as sns #for cool visualizations
import matplotlib.pyplot as plt #for visualizations
# %matplotlib inline

# %% [markdown]
# Data was scraped from the Denver Craigslist site via the Python package “Scrapy” which was initially built to scrape Craigslist sites for job postings and is easily modifiable to handle other Craigslist categories.

# %%
#Reading all necessary CSV files from Scrapy in the DIR
file_names = []
file_names = glob.glob('*.csv')

# %%
#Verify that file names loaded correctly
print(file_names)
# Out:
# ['test0.csv', 'test1.csv', 'test10.csv', 'test11.csv', 'test12.csv', 'test13.csv', 'test14.csv', 'test15.csv', 'test16.csv', 'test17.csv', 'test18.csv', 'test19.csv', 'test2.csv', 'test3.csv', 'test4.csv', 'test5.csv', 'test6.csv', 'test7.csv', 'test8.csv', 'test9.csv']

# %%
#Creating a dataframe from all of the CSV files
counter = 0
for file in file_names :
    print(file)
    if counter == 0 :
        temp_df = pd.read_csv(file, index_col=False)
        #print('Initial temp_df')
    if counter > 0 :
        temp_df1 = pd.read_csv(file, index_col=False)
        temp_df = temp_df.append(temp_df1)
    counter += 1
print('DONE LOADING FILES')
# Out:
# test0.csv
# test1.csv
# test10.csv
# test11.csv
# test12.csv
# test13.csv
# test14.csv
# test15.csv
# test16.csv
# test17.csv
# test18.csv
# test19.csv
# test2.csv
# test3.csv
# test4.csv
# test5.csv
# test6.csv
# test7.csv
# test8.csv
# test9.csv
# DONE LOADING FILES

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2400 entries, 0 to 119
# Data columns (total 2 columns):
# titles       2400 non-null object
# timestamp    2400 non-null object
# dtypes: object(2)
# memory usage: 56.2+ KB

# %%
temp_df.shape
# Out:
# (2400, 2)

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Steps required to cleanse and modify the data into a necessary format for analysis.
#
# 1.	Reset the index of the final data frame since multiple CSV files were loaded with records having the same index numbers.
# 2.	Drop duplicate records which removed 5 records.  I removed only duplicates that matched title and timestamp.  I also considered removing duplicates where ONLY the title matched but found that these were primarily different listings (e.g. microwave).
# 3.	Conversion of columns to proper types. ‘titles’ to string and ‘timestamp’ to an an actual timestamp object.
# 4.	Convert all words to lowercase for future analysis.
# 5.	Remove all characters and numbers.
# 6.	Remove all stop words.  Leverage NLTK ‘stopwords’ as the basis for the list. Add the word ‘free’ for this analysis since almost all of the listing titles are for free items. Parse each word in the titles list and if in the stop words list then remove, otherwise keep in the final list of titles to analyze.

# %%
#1 reset index so that we do not have issues since we loaded multiple files 
temp_df = temp_df.reset_index()[['titles', 'timestamp']]

# %%
#2 drop duplicate records
temp_df2 = temp_df.drop_duplicates()

# %%
# confirm records were dropped
temp_df2.shape
# Out:
# (2395, 2)

# %%
#3a Conversion of columns to proper types. ‘titles’ to string and ‘timestamp’ to an an actual timestamp object.
temp_df2['timestamp'] = pd.to_datetime(temp_df2['timestamp'],infer_datetime_format=True)
# Out:
# /Users/joshuaemayer/anaconda/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
temp_df2.sort_values(by='timestamp', ascending=True).head()
# Out:
#                         titles           timestamp
# 1439      free dirt + sod/turf 2017-08-24 19:44:00
# 1438                Free couch 2017-08-24 20:24:00
# 1437  Spalding basketball hoop 2017-08-24 21:23:00
# 1436                     Rocks 2017-08-24 21:38:00
# 1435    Southwestern Love Seat 2017-08-24 21:54:00

# %%
temp_df2.sort_values(by='timestamp', ascending=False).head()
# Out:
#                                    titles           timestamp
# 0                     Free Marcy el 1 pro 2017-10-04 21:19:00
# 1               36 inch Sony Trinitron TV 2017-10-04 21:17:00
# 2                               SCRAPPERS 2017-10-04 21:15:00
# 3  ** Case\Cover for Samsung Galaxy S8 ** 2017-10-04 20:54:00
# 4                            Moving Boxes 2017-10-04 20:53:00

# %%
#Understanding the total amount of time for the postings
temp_df2['timestamp'].max() - temp_df2['timestamp'].min()
# Out:
# Timedelta('41 days 01:35:00')

# %%
#3b Conversion of columns to proper types. ‘titles’ to string and ‘timestamp’ to an an actual timestamp object.
temp_df2['titles'] = temp_df2['titles'].astype(str)
# Out:
# /Users/joshuaemayer/anaconda/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#4 convert all characters to lower case
temp_df2['titles'] = temp_df2['titles'].str.lower()
# Out:
# /Users/joshuaemayer/anaconda/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Convert titles to a list for further scrubbing
titles_list = temp_df2['titles'].tolist()

# %%
#5 Filtering out all of the random characters
final_titles_list = []
for title in titles_list :
    title = re.sub('[^a-zA-Z]', ' ', title)
    #print(title)
    final_titles_list.append(title)

# %%
final_titles_list
# Out:
# ['free marcy el   pro',
#  '   inch sony trinitron tv',
#  'scrappers',
#  '   case cover for samsung galaxy s    ',
#  'moving boxes',
#  'free mirror ',
#  'halogen shop light',
#  'credenza',
#  'cabinets',
#  'curb alert',
#  'free fire wood',
#  'close up desk',
#  'aquarium  lights and accessories',
#  'free cardboard castle',
#  'fridge stopped working',
#  'futon mattress',
#  'firewood',
#  'free stuff westminster',
#  'king size bed frame new in box unused',
#  'electric fireplace   works on and off',
#  'border pavers',
#  'twin bed in unused new in box   no mattress or box springs',
#  'year old horse manure stirred best in town',
#  'styrofoam cooler with ice packs',
#  'free  new  ds zelda decal',
#  'free  vinyl mailers    ',
#  'free  packing material',
#  'free   books  books  books     boxes of mostly non fiction books',
#  'moving boxes',
#  'free   gallon buckets w  lids      gallon drums        value  free ',
#  'true     ci treadmill',
#  'pine roll top desk',
#  'free loveseat',
#  'free vintage borg bathroom scale  pink   vintage excellent cond ',
#  'free firewood',
#  'free pallets   good condition',
#  'free scrap',
#  'whole bunch o  metal landscape edging',
#  'beautiful mid  century console piano',
#  'office furniture',
#  'free plywood',
#  'concrete chunks for back fill  will deliver ',
#  'free leather couch loveseat',
#  'bucket of screws',
#  'free carbon fiber fender      accord',
#  'lots of free stuff',
#  'moving boxes',
#  'plywood and furring strips',
#  'metal ',
#  'curtains',
#  'free tables   kids slide  free tires',
#  'air hockey table',
#  'moving boxes pristine',
#  'fire wood for free',
#  'queen mattress  box spring  and frame',
#  'free  x galvanized base',
#  'clean  white fridge',
#  'file cabinets   bookcase',
#  'free storm door',
#  'free scrap hot water heater',
#  'free   porch swing   scrap metal',
#  'free woods',
#  'wood fence slats',
#  'many never used lcd screens still in static bags for old laptops',
#  'free river rocks  please take',
#  'television  free',
#  '  foot solid wood office doors',
#  'moving boxes  used once',
#  'moving boxes',
#  'crushed flagstone',
#  'free firewood  stuart st and ellsworth ave',
#  'free    book shelf and computer desk w  hutch',
#  'sofa and recliner',
#  'file cabinet on curb',
#  'shoe rack',
#  'baby photo album',
#  'wanted   martial arts gi pants  adult size   or  ',
#  'tv',
#  'several dozen    fluorescent light bulb tubes',
#  'baby boy photo scrapbooking album',
#  'free        wooden side rails',
#  'pool chemicals',
#  'the ultimate scrapbooking book',
#  'free lowrey magic genie tg     ',
#  'hospital bed  must be gone tonight ',
#  'wood  cedar  repurpose  reclaimed  x  fence posts',
#  'tv',
#  'free building materials   this friday   am',
#  'free upright piano',
#  'packing materials',
#  'firewood',
#  'wood pallets and   x   pieces',
#  'woodworking journals',
#  'solid oak entertainment center',
#  '  water heaters for scrap metal',
#  'ethan allen couch',
#  '  pallets',
#  'beds  desks  chairs  filing cabinets  stove  and more',
#  'free wood chip mulch',
#  '  piece reclining sectional',
#  'free fill dirt rock',
#  'dishwasher   works great just not needed anymore',
#  'scotsman ice maker   no bin',
#  'still have a lot of free clean fill dirt',
#  '  in sony tv',
#  '             f r e e      f i l l      d i r t             ',
#  'free danish mid century sofa',
#  'love seat',
#  'free furniture',
#  'free scrapwood  firewood  scrap  wood  pallets   pick up today        ',
#  'large cardboard boxes',
#  'queen size bed  mattress   box springs',
#  'matching desk and credenza',
#  '  pallets',
#  'two    inch flatscreens',
#  'new bathroom sink   single bowl mocha brown',
#  'free office chair',
#  'bookcase and luggage',
#  'oak tv cabinet',
#  'corner computer desk',
#  'concrete chunks',
#  'cabinets  shelves  drawers  cabinet doors',
#  'meter housing and cables   scrap metal',
#  'huge   pane window unit   x     and   hunter douglas blinds',
#  'computer office corner unit from show home free',
#  'manure compost',
#  'baby pigeon needs rehabilitation',
#  'free reclining rocking chair',
#  'behr upright piano',
#  'bookshelf n tv cabinet almost free',
#  'free misc',
#  'plumbers snake cable       ',
#  'solid wood entertainment cabinet',
#  'free items   chandeliers',
#  'neon  sign   come take it down and its  yours',
#  'free neon sign   you take it  down and  its yours',
#  'kids winter hats  gloves mittens',
#  'wood doors  cabinets  countertop',
#  'free tv sony',
#  'free firewood       call today     ',
#  'free bose    ',
#  'free   love seat',
#  'free fill dirt',
#  'couches',
#  'free    gallon water heater for scrap',
#  '   leather love seat',
#  'queen mattress and or box spring',
#  'red  luscious raspberries  splat hair dye',
#  'free cleaning   yard work',
#  'direct tv receiver and dish',
#  'playset',
#  'queen size mattress',
#  'free moving boxes',
#  'free desk on curb  still out as of  pm wednesday',
#  'free fill dirt   top soil    wheelbarrow ',
#  'free pallets',
#  '   year old sleep number mattress and controllers',
#  'char broil grill',
#  'queen box spring and metal frame',
#  'solar water heater panels',
#  'round rail fence posts',
#  'desk   filing cabinet',
#  'free firewood',
#  'free    leather love seat',
#  '    tv',
#  '   tires for your project  not hold air ',
#  'attn  scrappers',
#  'ugly  sturdy shelf   perfect for garage basement shed',
#  'free fence cedar fence panels',
#  'free fridge tredmill',
#  'yamaha organ   model e  ar',
#  'comfy recliner',
#  'free     mitsubishi tube tv         new',
#  'low carb baking mix',
#  'free fill dirt',
#  'high end mitsubishi tv with integrated stereo speakers      s',
#  'do you know how to knit or crochet  iso yarn and volunteer ',
#  'old physics math journals',
#  'free book shelf',
#  'baby bouncer',
#  'screen door',
#  'free pleather couch',
#  'free black futon mattress  full size ',
#  'kitchen cabinets',
#  'reclining love seat',
#  'free book case and more',
#  'burgandy recliner',
#  '   inch big screen tv mitsubishi',
#  'free firewood',
#  'like new standard size steel bathtub white right hand',
#  'toys',
#  'rocking chair king mattress',
#  'free fill dirt',
#  'free console tv',
#  'free couches',
#  'free firewood',
#  ' free  dresser  books  movies',
#  'free lava rock',
#  'free empty and clean beer bottles for home brewing',
#  'free pallets',
#  'washer dryer',
#  'credenza     ',
#  'house scheduled for demolition',
#  '  large safes    free scrap metal ',
#  'making kids smile for christmas',
#  'metal fencing and fence posts',
#  'harley mufflers',
#  'queen electric bed',
#  'sleeper couch',
#  'box of ceramic tile samples for crafting at curb',
#  'wing back overstuffed chair',
#  'kid ice hockey shirts and socks   free',
#  'couch for free ',
#  'free music stand',
#  'mirror  vanity mirror  bathroom cabinet  sink and faucet',
#  'free  x  hydro tray ',
#  'free retro lights  please come prepared to remove',
#  'munchkin diaper pail and jumparoo',
#  'sofa sleeper',
#  'still have a lot of free clean fill dirt',
#  'free hard firewood by lakeside amusement park  today only ',
#  'free womens clothes sm    ',
#  'curb alert ',
#  'computer cabinet',
#  '   gallon drum of oil',
#  'full mattress',
#  '  reclining couches',
#  'free volcano landscaping rocks',
#  'free fridge   no doors ',
#  'free dirt',
#  'full size bed',
#  'beer fridge   free',
#  'curb alert  sandbox  buckets  lawn furniture',
#  'used race car tires   free',
#  'desk and black leather couch',
#  'couch sleeper free',
#  'solid oak book case',
#  'free items',
#  'sony trinitron    with remote cable ready  great picture and sound',
#  'huge   pane window unit   x     and   hunter douglas blinds',
#  'queen mattress',
#  'tv stand',
#  'park hill',
#  'free     diagonal crt sylvania tv with remote',
#  'tv and remote',
#  'material spammer',
#  'free used toilet',
#  'free projection tv',
#  'over stuff chair  roll top desk',
#  'free basketball hoop',
#  '    sony lcd hdtv   broken lightbulb',
#  'car floor mats for      honda odyssey',
#  'granite pillars',
#  'moving boxes',
#  'free bricks',
#  'lowrey organ',
#  'free dirt',
#  'nebulizer',
#  'car seat  booster seats  sleeping bag  shade  cooler',
#  'landscape gravel',
#  'free for scrapping',
#  'trunk carpet for      camry',
#  'free potting soil',
#  'curb alert free',
#  'loveseat  reclining',
#  'range and dishwasher for free  fully functional',
#  'wagon  basketball hoop',
#  'brinkman grill',
#  'wood scraps',
#  'corvette news mag            promo brochures  binders',
#  'free sheet of drywall',
#  'free firewood   cutup wood from home project',
#  'free shower doors and sheets of glass',
#  'couch',
#  'sunday only',
#  'claw foot table  outdoor wicker table top  bed',
#  'two lawn mowers',
#  'furniture   misc need gone',
#  'free stainless steel fridge  needs work  looks great',
#  'yard ',
#  'many different items',
#  'micro fiber cream colored sectional',
#  'wine bottles',
#  '    free large tree branch    ',
#  'free fill dirt',
#  'free clean dirt',
#  'grill ',
#  'free small tv',
#  'free wood',
#  'oversized recliner',
#  'entertainment center',
#  'fill dirt',
#  'entertainment center',
#  'antique roll top desk   hand made',
#  'free couch sofa pull out bed',
#  'printer',
#  'large round fold up table',
#  'ethan allen table set   coffee table',
#  'free recliner and outdoor bench',
#  'bunk bed   ceiling mount',
#  'free appliances',
#  'total gym',
#  'free stuff',
#  'free recliners and end tables',
#  'love seat',
#  'free     flatscreen tv   broken screen',
#  'free firewood',
#  'ge mountable microwave',
#  'free entertainment center ',
#  'free pallets',
#  'free twin bedrails and box spring',
#  'free cabinet including sink',
#  'free bathrm vanity  bedframe  shelving and ventilation hood   cap hill',
#  'new kiddie pool  bike  potty  pallet wood',
#  'free stuff',
#  'free loveseat',
#  'free garage sale items',
#  'furniture misc free and tv',
#  'free couch',
#  'homemade dual     speaker box',
#  'refrigerator',
#  'bookshelf   feet by    ',
#  'free wood and filing cabinets',
#  'free stuff in the alley  city park west',
#  'two vintage     s shelving units   desk',
#  'free patio chairs',
#  'free leather couch',
#  'wine fridge',
#  'free ge dishwasher arm spray',
#  'projection tv',
#  'free home brew lids with grommets',
#  'exercise elliptical machine',
#  'free bird rabbit bedding',
#  'free honey oak inset panels and mantel like piece  plus scrap wood',
#  'basketball hoop',
#  'office desks commerical grade free',
#  'dog house  twin bed patio table golf cabinet',
#  'free     mitsubishi hdtv',
#  'free couch',
#  'white plastic containers w brown lids   oz qty   ',
#  'chicken coop',
#  'sofa',
#  'american furniture warehouse   office desk',
#  'garage sale',
#  'free fill dirt',
#  'free fill dirt',
#  'free fence wood',
#  'queen size mattress  ',
#  'free wood table and   chairs and heat lamp',
#  'free gas grill',
#  'free site to bring leftover landscape products  fill dirt  sand  ect',
#  'wood pallets free',
#  'free lawnmower',
#  'free filing cabinet',
#  '  plastic side tables',
#  ' changed to sun        free couch sofa and more',
#  'clearing house  furniture must go',
#  'free tv',
#  'free treadmill ',
#  'free well pressure tank  reuse or scrap metal',
#  'free bassett leather couch ',
#  'flip couch',
#  'tires for gardening',
#  'free chain link fencing and post',
#  'free recliner chair  very comfortable ',
#  'free fire wood',
#  'hot water heater',
#  'free blue iris',
#  'scrapers delight  stackable washer dryer for parts and  ',
#  'comfy red flower couch',
#  'solid oak desk  great condition',
#  'free mulch free',
#  'mid century modern executive desk and credenza',
#  'free scrap pallets',
#  'wooden table and chairs',
#  'free leather couch',
#  'brick rubble for fill',
#  'free doors',
#  'refridgerator free white',
#  'old denim jeans',
#  'pile of wood',
#  'free piano to anyone who can haul it',
#  'free firewood and kindling',
#  'free desk and office chair',
#  'i    mountain corridor official studies and newspaper articles',
#  'free woodchips ',
#  'random stuff',
#  'free    inch flat screen crt tv   silver jvc',
#  'pallets',
#  'desk chair',
#  'free wheelchair lift',
#  'recliner leather sofa  love seat and chair',
#  'kitchen table',
#  'free fill dirt',
#  'grill',
#  'conduit',
#  'scrapers delight  metal patio set plus chairs and table ',
#  'free moving boxes',
#  'leather couch',
#  'twin bed box spring and legs',
#  'free clean sand for sandbox',
#  'free wood posts',
#  'free pallet and boars',
#  'old water heater',
#  'free spa',
#  'free dishwasher',
#  'stuff for free',
#  'great propane grill',
#  'dark room trays and paper safe box',
#  'dirt   i load   you haul',
#  '  pallets',
#  'iso free desk craft table',
#  'free dirt and rocks',
#  'pallets',
#  'chain link fence',
#  'free appliances pick up today',
#  'stove  ge self cleaning free  longmont area',
#  'fire ash       great for gardens',
#  'packing paper',
#  'treadmill',
#  'free fill dirt near dtc',
#  'moving  free boxes ',
#  'free fridge and   dishwashers',
#  'lava rock',
#  'free  x  and installation',
#  'antique wood windows',
#  'free firewood',
#  'bedroom set',
#  'free stainless grill',
#  'yard swing',
#  'scrap metal',
#  'old polaroid     tv',
#  'grill',
#  'free cardboard and boxes',
#  'free pallets',
#  'free lamp ',
#  'dead water heater  doesn t leak  but is plugged somehow ',
#  'sony television',
#  'free tv     ',
#  'magic chef    foot fridge',
#  'free wood for firewood  more to come ',
#  'different shape foam pieces',
#  'free doctors choice denver mattress',
#  'media stand',
#  'free firewood',
#  'free rocks',
#  'free firewood logs cut up   ton s of logs call now ',
#  'free reclining leather couch',
#  'free boulders',
#  'dresser and queen metal bedframe',
#  'free out door chairs',
#  'free firewood',
#  'free wooden pallets',
#  'king size mattress',
#  'sofa and chair',
#  'sofa',
#  'free pallets',
#  'free queen size mattress',
#  'truck load of firewood free for mtn campfire  woodstove  bonfire',
#  'china cabinet',
#  'free firewood',
#  'free twin box spring',
#  'tires for projects not for cars',
#  'free dishwasher scrap',
#  'hitachi ultravision    inch projection tv',
#  '  free   filing cabinets  fireproofs  cubicle components',
#  'remodle panel  baseboard scrap metal',
#  'barn style shed',
#  'free moving boxes',
#  'sony    inch tv parts',
#  'free wood',
#  'lots of free packing paper',
#  'couch free',
#  '  free grills',
#  'george foreman  misc',
#  'chaise lounge sofa chair',
#  'free paper  chair  etc',
#  'solid oak shrunk',
#  '   inch mitsubishi big screen  free  ',
#  'antique strand bamboo  several hundred sq feet',
#  'free pea gravel',
#  'broken futon',
#  'free hot tub',
#  'free chair',
#  'upright piano   free  ',
#  'deck boards',
#  'couch and loveseat',
#  'free lava rock',
#  'free couch love seat and ottoman',
#  'free box spring  queen    two piece sectional couch',
#  'free reclining couch',
#  'curtis      and curtis      sg     envelopes',
#  'free shop vac  wood  pallets',
#  'beer brewing bomber bottles   free',
#  'physics study materials       and a box fan',
#  'queen box spring',
#  'wood fence panels',
#  'free clean fill dirt  landscaping  filling a pool ',
#  'free firewood',
#  'free rocks',
#  'free work shirts   best western',
#  'free dirt to good home',
#  'free candle wax for crafts',
#  'rocks',
#  'free moving packing paper',
#  'beautiful couch',
#  'free king size box springs   good condition',
#  'free large green couch in need of cleaning      ',
#  'file cabinet',
#  'tv and furniture',
#  'dresser mirror and cabinets',
#  'scrappers free water heater',
#  'spare tire',
#  'free firewood',
#  'free lazy boy recliner and or love seat',
#  'free camper top for truck',
#  'free dirt   get paid to pick up',
#  'new baby cereal dishwasher thing',
#  'free scrap metal',
#  'free trashcans    ',
#  'twin mattress  mid mod couch',
#  'free topsoil for your garden   lawn ',
#  'free moving boxes',
#  'leather couch and chase  bonded leather ',
#  'free fridge and freezer',
#  'free stuff',
#  'free couches',
#  'sleeper sofa',
#  'free   heavy  old   seater hot tub w  sides missing',
#  'free king size box spring and full size box spring',
#  'corner unit from show home',
#  'yard rocks ',
#  'large blue spruce tree  any community need a large holiday tree  ',
#  'free gravel   approx   f x   f',
#  'free fire wood',
#  'picture perfect big screen sony tv',
#  'china cabinet',
#  'free pine armoir  fabric chair and panasonic projector tv',
#  'scrap metal',
#  'dishwasher free   need gone asap',
#  'apprx   ton free road base',
#  'want free apricot wood ',
#  'ge smart water softening board and drive',
#  'all items left in house is free monday    pm',
#  'rich garden soil',
#  'free fill dirt',
#  'lawn edger',
#  'lawn edging',
#  '  piece desk',
#  'free cardboard boxes',
#  'double jogging stroller',
#  'free leather couch',
#  'queen bed frame and headboard',
#  'free couches   old  perfect for garage basement',
#  'free tv stand',
#  'free  old  used twin mattress',
#  'free samsung tv',
#  'free couch and ottoman',
#  'free compost',
#  'firewood',
#  'take my couch',
#  'golf bag cart',
#  '  decent spare tire         r  ',
#  'free stuff',
#  'free desk',
#  'yard sale',
#  'metal office cubicles',
#  'free desk',
#  'upholstered chair',
#  'huacaya alpacas',
#  'metal   glass   marble coffee table',
#  'free screened top soil',
#  'leather couch fair condition',
#  'free love seat   couch recliner  ft wide',
#  'moving boxes',
#  'free couch',
#  'giant foam block',
#  'leather fabric couch good condition',
#  'microwave',
#  'free rock',
#  'free brown leather   person couch',
#  'free rug pallet  glass and board',
#  'free furniture  antique furniture   modern  and misc  household items',
#  'free furniture items',
#  'free   custom cherry entertainment center',
#  'sofa mattress',
#  'free drywall',
#  'free mulch',
#  'more free rock    country cream ',
#  'full size dryer',
#  'free wood pallets',
#  '    tv sharp',
#  'free wood',
#  'entertainment center or storage unit',
#  'free couches at the curb   used',
#  'free stuff',
#  'free stainless steel fridge  needs new motor free',
#  'free wood  ',
#  'box of ceramic white wall tiles',
#  '  inch by   inch oak flooring',
#  '  brown leather sofas',
#  'kimball z    organ with cards',
#  'free couch  curbside pickup',
#  'two free chairs need reupholstering',
#  'freebie alert   yard sale leftovers',
#  'antique ladder',
#  'leftover wood',
#  'pipes abs pvc drainage underground sprinkler',
#  'free queen pillow top mattress',
#  'temp fencing',
#  'cement forms',
#  'tile couple of pallets',
#  '  free palets',
#  'metal all kinds green stakes pipes poles ect',
#  'free lumber and tjis',
#  'bluray remote',
#  'free fill dirt',
#  'upright piano  ',
#  'free river rock',
#  'stair lift',
#  'river rock',
#  'free items',
#  ' gone  see other sofa post   couch sofa w queen pull out',
#  'oem    z spoiler wing',
#  'pond goldfish free',
#  'couch sofa   dual recliner w hidden snack tray in middle',
#  'recliner   free',
#  'moving sale everything must go   ',
#  'free clean dirt   free delivery   free very clean dirt  we deliver   ',
#  'free desk',
#  'scrap wood for burning',
#  'free crib mattess',
#  'freezer need gone now ',
#  '  x     x     of them still have them',
#  'learning materials',
#  'dining room table',
#  'tons of free stuff',
#  'free armoire free',
#  'free brown leather  couch and ottoman',
#  'free leather sofa ',
#  'curb alert  salvageable couch and chair with rip',
#  'free ice cream',
#  'free fire wood',
#  'entertainment center',
#  'solid wood executive desk',
#  'headboard  footboard with broken leg  free ',
#  'free gas tank for a chrysler pickup',
#  'work bench  ft and wood shelf',
#  'boxes for free in driveway',
#  'free queen box spring',
#  'network cabinet',
#  'freezer',
#  'free',
#  'free dirt',
#  'work bench  ft',
#  '    crt colortv working with remote free',
#  'hp      inkjet broken  maybe good for parts ',
#  'free dirt   i will load with my tractor',
#  'hp photosmart printer',
#  'landscaping river rock',
#  'kitchen cabinets',
#  'free desk',
#  'everything on driveway is free',
#  'free hot tub',
#  'black file cabinet',
#  'chair and reclining love seat   free',
#  'free couches',
#  'kitchen countertops',
#  'free scrap steel',
#  'free moving boxes',
#  'free tv and couch',
#  'scrap lumber',
#  'interior doors',
#  'free american standard toilet',
#  'entertainment center or storage',
#  'lots of free stuff  must take it all tomorrow am',
#  '   inch coffee table',
#  'pallets',
#  'grill',
#  '    projection tv',
#  'free living family room furniture',
#  'garage drawer cabinet',
#  'scrap lumber',
#  'mulch natural color   cubic yards',
#  'gas line piping',
#  '  ft   leg ladder needs rebuilt',
#  'free firewood',
#  'littleton community pancake breakfast',
#  'broken down boxes',
#  'free computer desk and end table',
#  'media console',
#  'entertainment center',
#  'free telephone stand  free',
#  'parsons cleaner',
#  'varnish',
#  '    sony trinitron color tv',
#  'small stack of firewood',
#  'it s all free  bikes are gone ',
#  '   x         particle board',
#  'entertainment center',
#  'free firewood   broken pallets',
#  'wood',
#  'wood crates',
#  'old school sony tv  works',
#  'wooden shelf',
#  'pipe wrap insulation and insulated flex duct',
#  'tv    ',
#  'moving stuff',
#  'silky rooster',
#  'cherry wood armoire',
#  'lots of life left',
#  '  twin box springs free ',
#  'free swingset   jungle gym',
#  'free home depot boxes',
#  'free fill dirt   appx    yards',
#  'firewood  free  delivered',
#  'free couch',
#  'free soil or fill dirt ',
#  'swing set',
#  'lowery tg    organ free ',
#  'marcy home gym',
#  'nordic ice packs',
#  'tons of free books',
#  'free white fluff batting  from sofa cushions ',
#  'tan leather couch  free ',
#  'electric microfiber rocker recliner  free ',
#  'random invites for pp',
#  'free dirt',
#  'free ethan allen couch',
#  'free leather couch',
#  'packing paper   bubble wrap',
#  'afw recliner',
#  'laminate wood',
#  'free deck table and chairs',
#  'free filing cabinet',
#  'free taxidermy beetle bin',
#  '    hipster tv',
#  'free firewood',
#  'last day to get recliner couch ',
#  'hutch',
#  'free castiron sink',
#  'lots of free wood',
#  'landscaping wood chips mulch',
#  'free fire wood',
#  'free metal free metal free metal haul away asap   name is al',
#  'sofa',
#  'sorting boxes  mail boxes  pigeon holes',
#  'attn  scrappers',
#  'fill dirt',
#  'ugly but decent couch   free',
#  'firewood   maple trunk',
#  'silver maple mulch   curbside',
#  'looking for trashed out mini trampoline   needing frame',
#  'free cast iron for scrap',
#  'entertainment cabinet with tv',
#  'pallets    free',
#  'european style wardrobe',
#  'reclining couch  chair and loveseat',
#  '  pallets',
#  'free water heater for scrap',
#  'free pallets',
#  'entertainment center or storage',
#  'cat tower',
#  'free bureau desk thing',
#  'free barbecue',
#  'free grow gear',
#  'free sofa and loveseat',
#  'free marquis hot tub   you haul away ',
#  'free tv s',
#  'scrap wood christmas lights',
#  'free sand for playgrounds  etc ',
#  'pallets  lumber  firewood',
#  'free fill dirt',
#  'free wood',
#  '  used tires       r  ',
#  'end table printer stand',
#  'magazines',
#  'free pallets',
#  'dexa body scan   free',
#  'prescription pill bottles   empty   great for crafters ',
#  'free dirt',
#  'older dishwasher   works ',
#  'pottery barn couch  chair and ottoman',
#  'hot tub for free ',
#  'tv stand',
#  'free armoire',
#  'free    tv',
#  'free pallets',
#  'free leather sofa',
#  'dishwasher',
#  'free reclining couch',
#  'office desk',
#  'free fill dirt hampden and wadsworth area',
#  'free logs for firewood',
#  'camping grill',
#  'free firewood',
#  'luggage holder',
#  'deck boards',
#  'free furniture',
#  'kombucha scoby',
#  'free fresh mulch wood chips   free delivery    please read all info   ',
#  'wood desk',
#  'little tikes playset',
#  'free wood',
#  'free book shelf',
#  'grill scrap metal',
#  'decorations  free ',
#  'firewood',
#  'free monitor',
#  'free clean fill dirt',
#  'a clean queen size matress',
#  'free wood',
#  'twin xl boxspring',
#  'various wood doors',
#  'small entertainment center',
#  'dry cherry branches    ideal for wood smoking',
#  'entertainment center',
#  'faux sunset rock',
#  'reclining couch',
#  'free brown leather couch',
#  ' office desk ',
#  'free vintage wooden school desk',
#  'free metal desks and office dividers chairs',
#  'dead hot water heater',
#  'scrap or repair free washer',
#  'free refrigerator  working or scrap',
#  'free firewood',
#  'free red couch ',
#  'free reusable river rock',
#  'refrigerator use   scrap  pay you to take',
#  'free reusable rock',
#  'free pioneer elite big screen projection tv',
#  'metal',
#  'free dirt   free scrap metal',
#  'upholstered chairs',
#  'white leather corner seat',
#  'free landscape lumber     pieces  x  w rebar at each end',
#  'free wood pallet',
#  'free furniture',
#  'free construction wood ',
#  'fluorescent bulbs t   s      bulbs',
#  'free king size mattress and box spring',
#  'free and at the curb',
#  'stones',
#  'free scrap tin',
#  'free boxes       x    x   ',
#  'wood cabinets and appliances    free',
#  'free stuff',
#  '  free flat panel tv kit',
#  'free armoire for use or parts',
#  'free armoire',
#  '   gal free dirt',
#  'free grill',
#  'free box spring   king or two twins',
#  'free living room furniture',
#  'free moving boxes',
#  'free sofa couch',
#  'sofa sleeper',
#  'free fill dirt',
#  'free bed frame ikea',
#  'for teachers or homeschool',
#  'free fire wood logs',
#  'kenmore dishwasher',
#  'free rocks   updated ',
#  'free top soil and filler concrete',
#  'headlight brackets for           chevrolet cobalt   free',
#  'free kids pop up play house',
#  'free mulch wood chips',
#  'free reusable river rock',
#  'mattress king and queen   sofa',
#  'big screen tv',
#  'stove  fridge',
#  'fire wood',
#  'squat rack',
#  'free stuff',
#  'ones junk is someone else s treasure',
#  '    rims     hole',
#  '   free bestselling books ',
#  'oak desk',
#  'bike  garden supplies  party supplies  snowshoes  lumber',
#  '   inch tv set',
#  'glass tub shower doors',
#  'free entertainment center and or storage',
#  'free fill dirt',
#  'bedroom set',
#  'everything must go ',
#  'free matress',
#  'aluminum scraps',
#  'moving boxes and packing paper',
#  'free reusable river rock',
#  'metal  scrappers come get it ',
#  'metal desk  free',
#  'greek style frieze styrofoam art  made locally',
#  'free nutrient enriched planting soil   cubic yards',
#  'free fill dirt',
#  'free firewood you haul off',
#  'free dirt  ',
#  'twin bed bookshelf headboard',
#  'free camping stuff',
#  'crib mattress',
#  'storage emptied',
#  'recliner',
#  'free three ring binders',
#  'free bbq grill with side burner',
#  'coffee table',
#  'free items',
#  'stereo cabinet   black  multiple shelves  glass door on front',
#  'free leather couch   chair   ottoman',
#  'rooster',
#  'free entertainment center',
#  '    jvc tv',
#  'free scrap copper  about     pounds',
#  'yard sale left overs',
#  'mixed gray and rose colored rock',
#  'furniture',
#  'rooster with   toes',
#  'bookshelf',
#  'free scrap metal',
#  'free water heater for scrap',
#  'screen door',
#  'cardboard  boxes and scrap',
#  'free hardwood dresser',
#  '  norstar mics phone systems',
#  'panasonic tube tv',
#  'desk',
#  'hot water heater  scrap metal',
#  'free futon  i ll help load  just come take it tonight',
#  'wood paneling',
#  'scrap metal from shed',
#  'free mirror',
#  'couch for free',
#  'box of religious books',
#  'scrap metal  old futon frame ',
#  'free fill and top soil dirt',
#  'free wood',
#  ' free  pallets',
#  'free reusable river rock',
#  'free throw pillow insert for crafters',
#  'ikea kivik chaise longue cover   tullinge gray brown',
#  'free road base  sand  and gray breeze',
#  'free separated pallet wood',
#  'free bookshelf and or twin headboard',
#  'two twin box springs',
#  'free jacuzzi',
#  'tv stand with doors',
#  'free estate sale leftovers   ',
#  'attn soap  bath   body  crafters',
#  'tire and rim        r  ',
#  'free entertainment center',
#  'one grill and    gallon hot water heater',
#  'bathroom sinks  vanity and kitchen vent hood',
#  'original oil painting   wm nicol',
#  'free sofa loveseat',
#  'free pallets ',
#  ' gazelle  glider exerciser gone  to a good home ',
#  'free couch sofa',
#  'well loved sofa needs a new home ',
#  'free sofa   ',
#  'free lava rock',
#  'free wood and yard items',
#  'curb alert free washer',
#  'head board and footboard  barstools',
#  'hp all in one printer c       scanner works  printing doesn t',
#  'free comfy chair  free coffee table  free big tv',
#  'free holland lop',
#  'curb alert   free stuff',
#  'couch',
#  '  feet x   feet    glass',
#  'free couch near   th and ogden',
#  'pregnancy pillow',
#  'free male beta fish',
#  'clean screened dirt',
#  'small tv',
#  'fill dirt',
#  'free    drawer dresser',
#  'plastic and wood pallets',
#  'pearl izumi and sugoi mtb shorts and shirts   sizes m and l',
#  'tire for use as swing',
#  'free couch',
#  'curb alert old tools  pots  plant supports  small animal cage',
#  'free  benches  dog pen',
#  'free topsoil',
#  'bookshelf and or twin headboard',
#  'free lot of beckett s',
#  'curb alert   kids toys',
#  'double recliner couch',
#  'hd directv dish with stand',
#  'free furniture',
#  'pull out loveseat sofa',
#  'free kenmore elite top load washers max capac ',
#  'loveseat',
#  'free queen boxspring',
#  'free chair and ottoman',
#  'guitar boxes',
#  'free couch with extension in alley between gilpin and williams      so',
#  'free old decking wood',
#  'chairs free',
#  'plastic utensils',
#  'free mirror',
#  'free clean sand for sandbox',
#  ...]

# %%
#Create custom stop word list
stoplist = stopwords.words('english')
stoplist.append('free')
print(stoplist)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn', 'free']

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Most of the initial data analysis was regarding the shape of the words and their associated counts.  More advanced analysis will require unsupervised machine learning models to be created.

# %%
# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = stoplist) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(final_titles_list)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
#print(vocab)

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# %%
# Create pandas dataframe with words and counts for analysis
master_list = pd.DataFrame(
    {'Word': vocab,
     'Count': dist,
    })

# %%
master_list.sort_values(by='Count', ascending=False).head(10)
# Out:
#       Count      Word
# 1839    176      wood
# 379     163     couch
# 1732    114        tv
# 472      97      dirt
# 266      84     chair
# 176      81     boxes
# 1155     80   pallets
# 1415     71     scrap
# 456      69      desk
# 595      68  firewood

# %%
master_list.sort_values(by='Count', ascending=True).head(10)
# Out:
#       Count      Word
# 0         1   ability
# 1080      1  national
# 1079      1      name
# 1076      1  munchkin
# 1075      1  multiple
# 1074      1     multi
# 1072      1  mufflers
# 1071      1       mtn
# 1070      1      mths
# 1069      1       mtb

# %%
master_list.sort_values(by='Count', ascending=False).plot()
plt.show()

# %%
sns.distplot(master_list['Count'])

# %%
sns.distplot(master_list[master_list['Count'] < 5]['Count'])

# %%
master_list['Count'].describe()
# Out:
# count    1871.000000
# mean        3.799572
# std         9.784902
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max       176.000000
# Name: Count, dtype: float64

# %%
master_list[master_list['Count'] < 5]['Count'].describe()
# Out:
# count    1575.000000
# mean        1.475556
# std         0.835524
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: Count, dtype: float64
